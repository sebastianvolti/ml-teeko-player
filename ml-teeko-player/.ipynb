# %% [markdown]
# # Objetivo

# %% [markdown]
# Texto común

# %%
def codigo():
    pass

# %% [markdown]
# # Diseño

# %% [markdown]
# Texto común

# %%
def codigo():
    pass

# %% [markdown]
# # Experimentación

# %% [markdown]
# # Conclusión

# %% [markdown]
# # Bibliografía
